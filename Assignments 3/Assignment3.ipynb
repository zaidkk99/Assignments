# %%
#  Write a program that accepts a string from user. Your program should count and display number of vowels in that string.

# %%
str = input("Enter a String: ")
count=0
for x in str:
    if (x in 'aeiou'):
        count+=1
print(count)
# Out:
# Enter a String:  hello my name is zaid
# 7

# %%
'''  Write a program that reads a string from keyboard and display: 
* The number of uppercase letters in the string 
* The number of lowercase letters in the string 
* The number of digits in the string 
* The number of whitespace characters in the string  '''
# Out:
# '  Write a program that reads a string from keyboard and display: \n* The number of uppercase letters in the string \n* The number of lowercase letters in the string \n* The number of digits in the string \n* The number of whitespace characters in the string  '

# %%
str = input("Enter a String: ")
upper = 0
lower = 0
digit = 0
space = 0
for x in str:
   if x.isupper():
       upper+=1
   elif x.islower():
        lower+=1
   elif x.isdigit():
        digit+=1
   elif x.isspace():
        space+=1
print("Number of Uppercase in String:",upper)
print("Number of Lowercase in String:",lower)
print("Number of Digit in String:",digit)
print("Number of Space in String:",space)
# Out:
# Enter a String:  Hello My Name Is Zaid444
# Number of Uppercase in String: 5
# Number of Lowercase in String: 12
# Number of Digit in String: 3
# Number of Space in String: 4

# %%
'''  Write a Python program that accepts a string from user. Your program should create and display a 
new string where the first and last characters have been exchanged. 
For example if the user enters the string 'HELLO' then new string would be 'OELLH'  '''
# Out:
# "  Write a Python program that accepts a string from user. Your program should create and display a \nnew string where the first and last characters have been exchanged. \nFor example if the user enters the string 'HELLO' then new string would be 'OELLH'  "

# %%
str = input("Enter a String: ")
new_str = str[-1] + str[1:-1] + str[0]
print(new_str)
# Out:
# Enter a String:  HELLO
# OELLH

# %%
''' Write a Python program that accepts a string from user. Your program should create a new string in 
reverse of first string and display it. 
For example if the user enters the string 'EXAM' then new string would be 'MAXE' '''
# Out:
# " Write a Python program that accepts a string from user. Your program should create a new string in \nreverse of first string and display it. \nFor example if the user enters the string 'EXAM' then new string would be 'MAXE' "

# %%
str = input("Enter a String: ")
new_str = str[::-1]
print(new_str)
# Out:
# Enter a String:  EXAM
# MAXE

# %%
'''Write a Python program that accepts a string from user. Your program should create a new string by 
shifting one position to left. 
For example if the user enters the string 'examination 2021' then new string would be 'xamination 
2021e' '''
# Out:
# "Write a Python program that accepts a string from user. Your program should create a new string by \nshifting one position to left. \nFor example if the user enters the string 'examination 2021' then new string would be 'xamination \n2021e' "

# %%
str = input("Enter a String: ")
new_str = str[1::]+str[0]
print(new_str)
# Out:
# Enter a String:  examination 2021
# xamination 2021e

# %%
''' . Write a program that asks the user to input his name and print its initials. Assuming that the user 
always types first name, middle name and last name and does not include any unnecessary spaces. 
For example, if the user enters Ajay Kumar Garg the program should display A. K. G. 
Note:Don't use split() method  '''
# Out:
# " . Write a program that asks the user to input his name and print its initials. Assuming that the user \nalways types first name, middle name and last name and does not include any unnecessary spaces. \nFor example, if the user enters Ajay Kumar Garg the program should display A. K. G. \nNote:Don't use split() method  "

# %%
str = input("Enter your name: ")
for x in str:
    if x.isupper():
        print(x+".")
# Out:
# Enter your name:  Ajay Kumar Garg
# A.
# K.
# G.

# %%
''' A palindrome is a string that reads the same backward as forward. For example, the words dad, 
madam and radar are all palindromes. Write a programs that determines whether the string is a 
palindrome. 
Note: do not use reverse() method   '''
# Out:
# ' A palindrome is a string that reads the same backward as forward. For example, the words dad, \nmadam and radar are all palindromes. Write a programs that determines whether the string is a \npalindrome. \nNote: do not use reverse() method   '

# %%
str = input("Enter a String: ")
str = str.lower()
if str[0::] == str[::-1]:
    print("Yes")
else:
    print("No")
# Out:
# Enter a String:  Dad
# Yes

# %%
''' Write a program that display following output: 
SHIFT 
HIFTS 
IFTSH 
FTSHI 
TSHIF 
SHIFT '''
# Out:
# ' Write a program that display following output: \nSHIFT \nHIFTS \nIFTSH \nFTSHI \nTSHIF \nSHIFT '

# %%
str = "SHIFT"
n = len(str)
for x in range(n):
    out = str[x:] + str[:x] 
    print(out)
# Out:
# SHIFT
# HIFTS
# IFTSH
# FTSHI
# TSHIF

# %%
''' Write a program in python that accepts a string to setup a passwords. Your entered password must 
meet the following requirements: 
The password must be at least eight characters long. 
It must contain at least one uppercase letter. 
It must contain at least one lowercase letter. 
It must contain at least one numeric digit. 
Your program should should perform this validation.  '''
# Out:
# ' Write a program in python that accepts a string to setup a passwords. Your entered password must \nmeet the following requirements: \nThe password must be at least eight characters long. \nIt must contain at least one uppercase letter. \nIt must contain at least one lowercase letter. \nIt must contain at least one numeric digit. \nYour program should should perform this validation.  '

# %%
str = input("Enter a Password: ")
upper = False
lower = False
digit = False
for x in str:
    if x.isupper():
        upper = True
    elif x.islower():
        lower = True
    elif x.isdigit():
        digit = True
if len(str)>=8 and upper == True and lower == True and digit == True:
    print("Your Password is Setup.")
else:
    print("Your Password is not meeting the requirements.")
# Out:
# Enter a Password:  Zaidkhan12
# Your Password is Setup.
